# %% [markdown]
# <a href="https://colab.research.google.com/github/Deepak-Kumar123-creator/Prostate-Cancer/blob/main/prostate_cancer_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

df = pd.read_csv('/content/prostate.csv')

df

df.isnull().sum()

df.drop_duplicates

data = df.drop('ID',axis = 1)

data.head()

x = df.drop('PSA',axis = 1)

y = df['PSA']

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=1)

model = LinearRegression()

model.fit(x_train,y_train)

y_test = (y_test>=10).astype(int)

y_test

y_pred = model.predict(x_test)

y_pred = (y_pred>=10).astype(int)

y_pred

from sklearn.metrics import accuracy_score , precision_score , f1_score , recall_score

print(accuracy_score(y_test,y_pred),f1_score(y_test,y_pred),precision_score(y_test,y_pred)
,recall_score(y_test,y_pred)
)

from tensorflow.keras import models
# Out:
# 0.7105263157894737 0.7608695652173914 0.6363636363636364 0.9459459459459459

# %%
import pickle
filename = "prostate.pkl"
with open(filename, 'wb') as file:
    pickle.dump(model, file)
